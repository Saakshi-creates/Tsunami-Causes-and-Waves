# %% [markdown]
# # TSUNAMI CAUSES AND WAVES CAUSES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
source=pd.read_csv("C:\\Users\\Ksuma\\Desktop\\UPGRAD\\EDA\\sources.csv")

# %%
source.shape
# Out:
# (2582, 45)

# %%
waves=pd.read_csv("C:\\Users\\Ksuma\\Desktop\\UPGRAD\\EDA\\waves.csv")

# %%
waves.shape
# Out:
# (26203, 30)

# %%
source.head()
# Out:
#    SOURCE_ID  YEAR  MONTH  DAY  HOUR  MINUTE  CAUSE  VALIDITY  FOCAL_DEPTH  \
# 0          1 -2000    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 1          3 -1610    NaN  NaN   NaN     NaN    6.0       4.0          NaN
# 2          4 -1365    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 3          5 -1300    NaN  NaN   NaN     NaN    0.0       2.0          NaN
# 4          6  -760    NaN  NaN   NaN     NaN    0.0       2.0          NaN
#
#    PRIMARY_MAGNITUDE  ...  ALL_INJURIES INJURY_TOTAL ALL_FATALITIES  \
# 0                NaN  ...           NaN          NaN            NaN
# 1                NaN  ...           NaN          NaN            NaN
# 2                NaN  ...           NaN          NaN            NaN
# 3                6.0  ...           NaN          NaN            NaN
# 4                NaN  ...           NaN          NaN            NaN
#
#   FATALITY_TOTAL  ALL_DAMAGE_MILLIONS  DAMAGE_TOTAL  ALL_HOUSES_DAMAGED  \
# ...

# %%
waves.head()
# Out:
#    SOURCE_ID  WAVE_ID  YEAR  MONTH  DAY  REGION_CODE COUNTRY STATE/PROVINCE  \
# 0          1    11014 -2000    NaN  NaN         50.0   SYRIA            NaN
# 1          3    17601 -1610    NaN  NaN         50.0   SYRIA            NaN
# 2          3        1 -1610    NaN  NaN         50.0  GREECE            NaN
# 3          9        2  -479    NaN  NaN         50.0  GREECE            NaN
# 4         10    19364  -426    6.0  NaN         50.0  GREECE            NaN
#
#                 LOCATION  LATITUDE  ...  INJURIES  INJURY_ESTIMATE  \
# 0                 UGARIT    35.583  ...       NaN              NaN
# 1                 UGARIT    35.583  ...       NaN              NaN
# 2  N. AND E. COAST CRETE    35.500  ...       NaN              NaN
# 3    POTIDAEA, MACEDONIA    40.300  ...       NaN              NaN
# 4                  TARFI       NaN  ...       NaN              NaN
#
#    FATALITIES  FATALITY_ESTIMATE DAMAGE_MILLIONS_DOLLARS  DAMAGE_ESTIMATE  \
# ...

# %%
waves.describe()
# Out:
#           SOURCE_ID       WAVE_ID          YEAR         MONTH           DAY  \
# count  26203.000000  26203.000000  26203.000000  26099.000000  25990.000000
# mean    3146.880434  16701.682937   1959.461207      6.133990     15.326048
# std     1718.398292   8999.325433    135.750038      3.504212      8.519406
# min        1.000000      1.000000  -2000.000000      1.000000      1.000000
# 25%     1884.000000   9393.500000   1952.000000      3.000000     11.000000
# 50%     2406.000000  16986.000000   1996.000000      5.000000     12.000000
# 75%     5413.000000  23998.500000   2011.000000      9.000000     23.000000
# max     5642.000000  32418.000000   2017.000000     12.000000     31.000000
#
#         REGION_CODE      LATITUDE     LONGITUDE  DISTANCE_FROM_SOURCE  \
# count  26202.000000  25591.000000  25591.000000          25320.000000
# mean      80.779330     21.819451     50.248786           2463.739573
# std        9.637029     24.936755    121.136966           4217.066399
# ...

# %%
source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2582 entries, 0 to 2581
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SOURCE_ID                   2582 non-null   int64
#  1   YEAR                        2582 non-null   int64
#  2   MONTH                       2443 non-null   float64
#  3   DAY                         2341 non-null   float64
#  4   HOUR                        1319 non-null   float64
#  5   MINUTE                      1233 non-null   float64
#  6   CAUSE                       2576 non-null   float64
#  7   VALIDITY                    2580 non-null   float64
#  8   FOCAL_DEPTH                 867 non-null    float64
#  9   PRIMARY_MAGNITUDE           1459 non-null   float64
#  10  REGION_CODE                 2581 non-null   float64
#  11  COUNTRY                     2581 non-null   object
#  12  STATE/PROVINCE              293 non-null    object
# ...

# %%
waves.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26203 entries, 0 to 26202
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SOURCE_ID                   26203 non-null  int64
#  1   WAVE_ID                     26203 non-null  int64
#  2   YEAR                        26203 non-null  int64
#  3   MONTH                       26099 non-null  float64
#  4   DAY                         25990 non-null  float64
#  5   REGION_CODE                 26202 non-null  float64
#  6   COUNTRY                     26200 non-null  object
#  7   STATE/PROVINCE              21006 non-null  object
#  8   LOCATION                    26198 non-null  object
#  9   LATITUDE                    25591 non-null  float64
#  10  LONGITUDE                   25591 non-null  float64
#  11  DISTANCE_FROM_SOURCE        25320 non-null  float64
#  12  TRAVEL_TIME_HOURS           3272 non-null   float64
# ...

# %%
source.isnull().sum()
# Out:
# SOURCE_ID                        0
# YEAR                             0
# MONTH                          139
# DAY                            241
# HOUR                          1263
# MINUTE                        1349
# CAUSE                            6
# VALIDITY                         2
# FOCAL_DEPTH                   1715
# PRIMARY_MAGNITUDE             1123
# REGION_CODE                      1
# COUNTRY                          1
# STATE/PROVINCE                2289
# LOCATION                        12
# LATITUDE                       359
# LONGITUDE                      360
# MAXIMUM_HEIGHT                1540
# MAGNITUDE_ABE                 2582
# MAGNITUDE_IIDA                1841
# INTENSITY_SOLOVIEV            1358
# WARNING_STATUS                2531
# MISSING                       2526
# MISSING_ESTIMATE              2514
# INJURIES                      2578
# INJURY_ESTIMATE               2578
# FATALITIES                    2346
# FATALITY_ESTIMATE             2258
# ...

# %%
waves.isnull().sum()
# Out:
# SOURCE_ID                         0
# WAVE_ID                           0
# YEAR                              0
# MONTH                           104
# DAY                             213
# REGION_CODE                       1
# COUNTRY                           3
# STATE/PROVINCE                 5197
# LOCATION                          5
# LATITUDE                        612
# LONGITUDE                       612
# DISTANCE_FROM_SOURCE            883
# TRAVEL_TIME_HOURS             22931
# TRAVEL_TIME_MINUTES           22956
# VALIDITY                      25876
# MEASUREMENT_TYPE                289
# PERIOD                        23977
# FIRST_MOTION                  24652
# MAXIMUM_HEIGHT                 3874
# HORIZONTAL_INUNDATION         17412
# INJURIES                      26080
# INJURY_ESTIMATE               26074
# FATALITIES                    25520
# FATALITY_ESTIMATE             25299
# DAMAGE_MILLIONS_DOLLARS       26068
# DAMAGE_ESTIMATE               24316
# ...

# %% [markdown]
# # DATA CLEANING

# %%
source.columns
# Out:
# Index(['SOURCE_ID', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'CAUSE',
#        'VALIDITY', 'FOCAL_DEPTH', 'PRIMARY_MAGNITUDE', 'REGION_CODE',
#        'COUNTRY', 'STATE/PROVINCE', 'LOCATION', 'LATITUDE', 'LONGITUDE',
#        'MAXIMUM_HEIGHT', 'MAGNITUDE_ABE', 'MAGNITUDE_IIDA',
#        'INTENSITY_SOLOVIEV', 'WARNING_STATUS', 'MISSING', 'MISSING_ESTIMATE',
#        'INJURIES', 'INJURY_ESTIMATE', 'FATALITIES', 'FATALITY_ESTIMATE',
#        'DAMAGE_MILLIONS_DOLLARS', 'DAMAGE_ESTIMATE', 'HOUSES_DAMAGED',
#        'HOUSE_DAMAGE_ESTIMATE', 'HOUSES_DESTROYED',
#        'HOUSE_DESTRUCTION_ESTIMATE', 'ALL_MISSING', 'MISSING_TOTAL',
#        'ALL_INJURIES', 'INJURY_TOTAL', 'ALL_FATALITIES', 'FATALITY_TOTAL',
#        'ALL_DAMAGE_MILLIONS', 'DAMAGE_TOTAL', 'ALL_HOUSES_DAMAGED',
#        'HOUSE_DAMAGE_TOTAL', 'ALL_HOUSES_DESTROYED',
#        'HOUSE_DESTRUCTION_TOTAL'],
#       dtype='object')

# %%
#DELETING THE COLUMNS WITH THE LEAST NUMBER OF VALUES PRESENT
#For sources and waves we will calculate the percentage of values present with respect to the total values

percent_missing_source = source.isnull().sum() * 100 / len(source)
percent_missing_source
# Out:
# SOURCE_ID                       0.000000
# YEAR                            0.000000
# MONTH                           5.383424
# DAY                             9.333850
# HOUR                           48.915569
# MINUTE                         52.246321
# CAUSE                           0.232378
# VALIDITY                        0.077459
# FOCAL_DEPTH                    66.421379
# PRIMARY_MAGNITUDE              43.493416
# REGION_CODE                     0.038730
# COUNTRY                         0.038730
# STATE/PROVINCE                 88.652208
# LOCATION                        0.464756
# LATITUDE                       13.903950
# LONGITUDE                      13.942680
# MAXIMUM_HEIGHT                 59.643687
# MAGNITUDE_ABE                 100.000000
# MAGNITUDE_IIDA                 71.301317
# INTENSITY_SOLOVIEV             52.594888
# WARNING_STATUS                 98.024787
# MISSING                        97.831139
# MISSING_ESTIMATE               97.366383
# ...

# %%
percent_missing_waves=100*(waves.isnull().sum())/(len(waves))
percent_missing_waves
# Out:
# SOURCE_ID                      0.000000
# WAVE_ID                        0.000000
# YEAR                           0.000000
# MONTH                          0.396901
# DAY                            0.812884
# REGION_CODE                    0.003816
# COUNTRY                        0.011449
# STATE/PROVINCE                19.833607
# LOCATION                       0.019082
# LATITUDE                       2.335610
# LONGITUDE                      2.335610
# DISTANCE_FROM_SOURCE           3.369843
# TRAVEL_TIME_HOURS             87.512880
# TRAVEL_TIME_MINUTES           87.608289
# VALIDITY                      98.752051
# MEASUREMENT_TYPE               1.102927
# PERIOD                        91.504790
# FIRST_MOTION                  94.080830
# MAXIMUM_HEIGHT                14.784567
# HORIZONTAL_INUNDATION         66.450406
# INJURIES                      99.530588
# INJURY_ESTIMATE               99.507690
# FATALITIES                    97.393428
# ...

# %%
#Dropping the columns with more than 80% of empty rows

percent_missing_source_delete=percent_missing_source[percent_missing_source>80]
percent_missing_source_delete

percent_missing_waves_delete=percent_missing_waves[percent_missing_waves>80]
percent_missing_waves_delete
# Out:
# TRAVEL_TIME_HOURS             87.512880
# TRAVEL_TIME_MINUTES           87.608289
# VALIDITY                      98.752051
# PERIOD                        91.504790
# FIRST_MOTION                  94.080830
# INJURIES                      99.530588
# INJURY_ESTIMATE               99.507690
# FATALITIES                    97.393428
# FATALITY_ESTIMATE             96.550013
# DAMAGE_MILLIONS_DOLLARS       99.484792
# DAMAGE_ESTIMATE               92.798535
# HOUSES_DAMAGED                99.381750
# HOUSE_DAMAGE_ESTIMATE         98.465825
# HOUSES_DESTROYED              98.885624
# HOUSE_DESTRUCTION_ESTIMATE    97.107201
# dtype: float64

# %%
#Creating a new dataset for source as "s" and waves as "w" so that we can look at the insights that these less than 20% values can provide us with

s=source
w=waves

s.shape
# Out:
# (2582, 45)

# %%
s.drop(columns=percent_missing_source_delete.index,inplace=True)

# %%
s.shape
# Out:
# (2582, 23)

# %%
w.shape
# Out:
# (26203, 30)

# %%
w.drop(columns=percent_missing_waves_delete.index,inplace=True)

# %%
w.shape
# Out:
# (26203, 15)

# %% [markdown]
# ## Thus we can see that we're only left with 15 major columns in waves dataset with 26203 row values and as for the source, we're left with 23 columns and 2582 rows.

# %%
#dataset after the major columns

s.head()
# Out:
#    SOURCE_ID  YEAR  MONTH  DAY  HOUR  MINUTE  CAUSE  VALIDITY  FOCAL_DEPTH  \
# 0          1 -2000    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 1          3 -1610    NaN  NaN   NaN     NaN    6.0       4.0          NaN
# 2          4 -1365    NaN  NaN   NaN     NaN    1.0       1.0          NaN
# 3          5 -1300    NaN  NaN   NaN     NaN    0.0       2.0          NaN
# 4          6  -760    NaN  NaN   NaN     NaN    0.0       2.0          NaN
#
#    PRIMARY_MAGNITUDE  ...  LATITUDE LONGITUDE MAXIMUM_HEIGHT  MAGNITUDE_IIDA  \
# 0                NaN  ...    35.683     35.80            NaN             NaN
# 1                NaN  ...    36.400     25.40           90.0             NaN
# 2                NaN  ...    35.683     35.80            NaN             NaN
# 3                6.0  ...    39.960     26.24            NaN             NaN
# 4                NaN  ...       NaN       NaN            NaN             NaN
#
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2582 entries, 0 to 2581
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SOURCE_ID                2582 non-null   int64
#  1   YEAR                     2582 non-null   int64
#  2   MONTH                    2443 non-null   float64
#  3   DAY                      2341 non-null   float64
#  4   HOUR                     1319 non-null   float64
#  5   MINUTE                   1233 non-null   float64
#  6   CAUSE                    2576 non-null   float64
#  7   VALIDITY                 2580 non-null   float64
#  8   FOCAL_DEPTH              867 non-null    float64
#  9   PRIMARY_MAGNITUDE        1459 non-null   float64
#  10  REGION_CODE              2581 non-null   float64
#  11  COUNTRY                  2581 non-null   object
#  12  LOCATION                 2570 non-null   object
#  13  LATITUDE                 2223 non-null   float64
# ...

# %%
w.head()
# Out:
#    SOURCE_ID  WAVE_ID  YEAR  MONTH  DAY  REGION_CODE COUNTRY STATE/PROVINCE  \
# 0          1    11014 -2000    NaN  NaN         50.0   SYRIA            NaN
# 1          3    17601 -1610    NaN  NaN         50.0   SYRIA            NaN
# 2          3        1 -1610    NaN  NaN         50.0  GREECE            NaN
# 3          9        2  -479    NaN  NaN         50.0  GREECE            NaN
# 4         10    19364  -426    6.0  NaN         50.0  GREECE            NaN
#
#                 LOCATION  LATITUDE  LONGITUDE  DISTANCE_FROM_SOURCE  \
# 0                 UGARIT    35.583      35.75                  12.0
# 1                 UGARIT    35.583      35.75                 935.0
# 2  N. AND E. COAST CRETE    35.500      25.00                 106.0
# 3    POTIDAEA, MACEDONIA    40.300      23.33                  67.0
# 4                  TARFI       NaN        NaN                   NaN
#
#    MEASUREMENT_TYPE  MAXIMUM_HEIGHT  HORIZONTAL_INUNDATION
# ...

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26203 entries, 0 to 26202
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SOURCE_ID              26203 non-null  int64
#  1   WAVE_ID                26203 non-null  int64
#  2   YEAR                   26203 non-null  int64
#  3   MONTH                  26099 non-null  float64
#  4   DAY                    25990 non-null  float64
#  5   REGION_CODE            26202 non-null  float64
#  6   COUNTRY                26200 non-null  object
#  7   STATE/PROVINCE         21006 non-null  object
#  8   LOCATION               26198 non-null  object
#  9   LATITUDE               25591 non-null  float64
#  10  LONGITUDE              25591 non-null  float64
#  11  DISTANCE_FROM_SOURCE   25320 non-null  float64
#  12  MEASUREMENT_TYPE       25914 non-null  float64
#  13  MAXIMUM_HEIGHT         22329 non-null  float64
# ...

# %%
print(s.isnull().sum())
print(w.isnull().sum())
# Out:
# SOURCE_ID                     0
# YEAR                          0
# MONTH                       139
# DAY                         241
# HOUR                       1263
# MINUTE                     1349
# CAUSE                         6
# VALIDITY                      2
# FOCAL_DEPTH                1715
# PRIMARY_MAGNITUDE          1123
# REGION_CODE                   1
# COUNTRY                       1
# LOCATION                     12
# LATITUDE                    359
# LONGITUDE                   360
# MAXIMUM_HEIGHT             1540
# MAGNITUDE_IIDA             1841
# INTENSITY_SOLOVIEV         1358
# DAMAGE_ESTIMATE            2042
# ALL_FATALITIES             2060
# FATALITY_TOTAL             1929
# DAMAGE_TOTAL               1576
# HOUSE_DESTRUCTION_TOTAL    2007
# dtype: int64
# SOURCE_ID                    0
# WAVE_ID                      0
# YEAR                         0
# MONTH                      104
# DAY                        213
# REGION_CODE                  1
# ...

# %% [markdown]
# ## Filling the null values which are of float type in waves and source

# %%
# Null values in Source dataframe

s.describe()

# Except for country and location we can impute the values for the rest of the columns because we shouldn't just consider a random place as per mode value.
# We wil be imputing them with float values
# Out:
#          SOURCE_ID         YEAR        MONTH          DAY         HOUR  \
# count  2582.000000  2582.000000  2443.000000  2341.000000  1319.000000
# mean   2132.966692  1805.891944     6.621367    15.618539    11.319939
# std    1546.994278   350.752703     3.486535     8.680274     6.929352
# min       1.000000 -2000.000000     1.000000     1.000000     0.000000
# 25%     940.250000  1818.000000     4.000000     8.000000     5.000000
# 50%    1797.500000  1895.000000     7.000000    16.000000    11.000000
# 75%    3148.750000  1956.000000    10.000000    23.000000    17.000000
# max    5642.000000  2017.000000    12.000000    31.000000    23.000000
#
#             MINUTE        CAUSE     VALIDITY  FOCAL_DEPTH  PRIMARY_MAGNITUDE  \
# count  1233.000000  2576.000000  2580.000000   867.000000        1459.000000
# mean     28.225466     1.786879     2.334109    36.205306           7.038725
# std      17.202228     2.260681     1.558476    37.163354           0.803739
# ...

# %%
s.columns
# Out:
# Index(['SOURCE_ID', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'CAUSE',
#        'VALIDITY', 'FOCAL_DEPTH', 'PRIMARY_MAGNITUDE', 'REGION_CODE',
#        'COUNTRY', 'LOCATION', 'LATITUDE', 'LONGITUDE', 'MAXIMUM_HEIGHT',
#        'MAGNITUDE_IIDA', 'INTENSITY_SOLOVIEV', 'DAMAGE_ESTIMATE',
#        'ALL_FATALITIES', 'FATALITY_TOTAL', 'DAMAGE_TOTAL',
#        'HOUSE_DESTRUCTION_TOTAL'],
#       dtype='object')

# %%
w.columns
# Out:
# Index(['SOURCE_ID', 'WAVE_ID', 'YEAR', 'MONTH', 'DAY', 'REGION_CODE',
#        'COUNTRY', 'STATE/PROVINCE', 'LOCATION', 'LATITUDE', 'LONGITUDE',
#        'DISTANCE_FROM_SOURCE', 'MEASUREMENT_TYPE', 'MAXIMUM_HEIGHT',
#        'HORIZONTAL_INUNDATION'],
#       dtype='object')

# %%
# We'll do the uni-variate analysis on these columns and fill the values accordingly

# %%
# Imputing null vaues in waves dataset

# We won't be imputing values for the  'COUNTRY', 'STATE/PROVINCE', 'LOCATION' columns because these are of object type and we cannot just take the mode of a random location 
#['SOURCE_ID', 'WAVE_ID', 'YEAR', 'MONTH', 'DAY', 'REGION_CODE', 'LATITUDE', 'LONGITUDE','DISTANCE_FROM_SOURCE', 'MEASUREMENT_TYPE', 'MAXIMUM_HEIGHT']
#w['MONTH', 'DAY', 'REGION_CODE', 'LATITUDE', 'LONGITUDE','DISTANCE_FROM_SOURCE', 'MEASUREMENT_TYPE', 'MAXIMUM_HEIGHT'].fillna(round(w['MONTH', 'DAY', 'REGION_CODE', 'LATITUDE', 'LONGITUDE','DISTANCE_FROM_SOURCE', 'MEASUREMENT_TYPE', 'MAXIMUM_HEIGHT'].median(),2),inplace=True)

w["MONTH"].fillna(round(w["MONTH"].median(),2),inplace=True)

# %%
w.isnull().sum()
# Out:
# SOURCE_ID                    0
# WAVE_ID                      0
# YEAR                         0
# MONTH                        0
# DAY                          0
# REGION_CODE                  0
# COUNTRY                      0
# STATE/PROVINCE            5071
# LOCATION                     0
# LATITUDE                   589
# LONGITUDE                  589
# DISTANCE_FROM_SOURCE       823
# MEASUREMENT_TYPE           287
# MAXIMUM_HEIGHT            3682
# HORIZONTAL_INUNDATION    17200
# dtype: int64

# %%
#Since the values were very low for these specific columns thus we will remove them
w = w[w['REGION_CODE'].notna()]
w = w[w['DAY'].notna()]
w = w[w['COUNTRY'].notna()]
w = w[w['LOCATION'].notna()]

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25982 entries, 25 to 26202
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SOURCE_ID              25982 non-null  int64
#  1   WAVE_ID                25982 non-null  int64
#  2   YEAR                   25982 non-null  int64
#  3   MONTH                  25982 non-null  float64
#  4   DAY                    25982 non-null  float64
#  5   REGION_CODE            25982 non-null  float64
#  6   COUNTRY                25982 non-null  object
#  7   STATE/PROVINCE         20911 non-null  object
#  8   LOCATION               25982 non-null  object
#  9   LATITUDE               25393 non-null  float64
#  10  LONGITUDE              25393 non-null  float64
#  11  DISTANCE_FROM_SOURCE   25159 non-null  float64
#  12  MEASUREMENT_TYPE       25695 non-null  float64
#  13  MAXIMUM_HEIGHT         22300 non-null  float64
# ...

# %%
s.isnull().sum()
# Out:
# SOURCE_ID                     0
# YEAR                          0
# MONTH                       137
# DAY                         239
# HOUR                       1252
# MINUTE                     1337
# CAUSE                         0
# VALIDITY                      0
# FOCAL_DEPTH                1700
# PRIMARY_MAGNITUDE          1109
# REGION_CODE                   0
# COUNTRY                       0
# LOCATION                      0
# LATITUDE                    354
# LONGITUDE                   355
# MAXIMUM_HEIGHT             1523
# MAGNITUDE_IIDA             1821
# INTENSITY_SOLOVIEV         1338
# DAMAGE_ESTIMATE            2024
# ALL_FATALITIES             2042
# FATALITY_TOTAL             1911
# DAMAGE_TOTAL               1560
# HOUSE_DESTRUCTION_TOTAL    1990
# dtype: int64

# %%
s = s[s['CAUSE'].notna()]
s = s[s['VALIDITY'].notna()]
s = s[s['REGION_CODE'].notna()]
s = s[s['COUNTRY'].notna()]
s = s[s['LOCATION'].notna()]

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2562 entries, 0 to 2581
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SOURCE_ID                2562 non-null   int64
#  1   YEAR                     2562 non-null   int64
#  2   MONTH                    2425 non-null   float64
#  3   DAY                      2323 non-null   float64
#  4   HOUR                     1310 non-null   float64
#  5   MINUTE                   1225 non-null   float64
#  6   CAUSE                    2562 non-null   float64
#  7   VALIDITY                 2562 non-null   float64
#  8   FOCAL_DEPTH              862 non-null    float64
#  9   PRIMARY_MAGNITUDE        1453 non-null   float64
#  10  REGION_CODE              2562 non-null   float64
#  11  COUNTRY                  2562 non-null   object
#  12  LOCATION                 2562 non-null   object
#  13  LATITUDE                 2208 non-null   float64
# ...

# %%
#DOING UNI-VARIATE ANALYSIS FOR EACH COLUMN

'''LATITUDE                   589
LONGITUDE                  589
DISTANCE_FROM_SOURCE       823
MEASUREMENT_TYPE           287
MAXIMUM_HEIGHT            3682
HORIZONTAL_INUNDATION  '''

plt,ax=plt.subplots(nrows=2,ncols=2,figsize=(6,6))
ax[0,0].hist (column='LATITUDE', grid=False, edgecolor='black') # The top-left axes
ax[0,1].hist (column='LONGITUDE', grid=False, edgecolor='black') # The top-right axes
ax[1,0].hist (column='DISTANCE_FROM_SOURCE', grid=False, edgecolor='black') # The bottom-left axes
ax[1,1].hist (column='MEASUREMENT_TYPE', grid=False, edgecolor='black') # The bottom-right axes
# w.hist(column='LATITUDE', grid=False, edgecolor='black')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15008/523178083.py in <module>
#       9
#      10 plt,ax=plt.subplots(nrows=2,ncols=2,figsize=(6,6))
# ---> 11 ax[0,0].hist (column='LATITUDE', grid=False, edgecolor='black') # The top-left axes
#      12 ax[0,1].hist (column='LONGITUDE', grid=False, edgecolor='black') # The top-right axes
#      13 ax[1,0].hist (column='DISTANCE_FROM_SOURCE', grid=False, edgecolor='black') # The bottom-left axes
#
# ~\ANACONDA\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'
